# %% [markdown]
# Installations

# %%
# Set non-interactive mode
# !export DEBIAN_FRONTEND=noninteractive  > /dev/null 2>&1

# Preconfigure the keyboard layout selections directly
# !echo "keyboard-configuration keyboard-configuration/layoutcode select English (US)" | sudo debconf-set-selections  > /dev/null 2>&1
# !echo "keyboard-configuration keyboard-configuration/variantcode select English (US)" | sudo debconf-set-selections  > /dev/null 2>&1

# Install keyboard-configuration (after preconfiguring it)
# !sudo DEBIAN_FRONTEND=noninteractive apt-get install -y keyboard-configuration > /dev/null 2>&1

# Install cuda 11.8
# !sudo DEBIAN_FRONTEND=noninteractive apt-get upgrade -y  > /dev/null 2>&1
# !sudo DEBIAN_FRONTEND=noninteractive apt-get install -y cuda-11-8  > /dev/null 2>&1

# Configure environment variables for CUDA
import os
os.environ['CUDA_HOME'] = '/usr/local/cuda-11.8'
os.environ['PATH'] = '/usr/local/cuda-11.8/bin:' + os.environ['PATH']
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda-11.8/lib64:' + os.environ.get('LD_LIBRARY_PATH', '')

# %%
# converting to torch
# !pip uninstall -y torch torchvision torchaudio torchtext > /dev/null 2>&1
# !pip cache purge > /dev/null 2>&1

# !pip install torch==2.1.0+cu118 torchvision==0.16.0+cu118 torchaudio==2.1.0+cu118 --index-url https://download.pytorch.org/whl/cu118 > /dev/null 2>&1
# !pip install xformers==0.0.22.post4 --index-url https://download.pytorch.org/whl/cu118 > /dev/null 2>&1

# %%
import torch
import torchvision
import torchaudio

print("Torch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("Torchaudio version:", torchaudio.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Torch version: 2.1.0+cu118
# Torchvision version: 0.16.0+cu118
# Torchaudio version: 2.1.0+cu118
# CUDA available: True
# CUDA version: 11.8

# %%
# datasets
# !pip install datasets  > /dev/null 2>&1
# !pip install nerfacc  > /dev/null 2>&1
# !pip install jedi > /dev/null 2>&1

from datasets import load_dataset
from PIL import Image
import os

# Fourier123
# !git clone https://github.com/Ysz2022/Fourier123 > /dev/null 2>&1
# %cd Fourier123
# !pip install -r requirements.txt > /dev/null 2>&1

# nvdiffrast
# !git clone https://github.com/NVlabs/nvdiffrast.git > /dev/null 2>&1
# %cd nvdiffrast
# !python setup.py install > /dev/null 2>&1
# %cd ..

# kiuikit
# !git clone https://github.com/ashawkey/kiuikit.git > /dev/null 2>&1
# %cd kiuikit
# !python setup.py install > /dev/null 2>&1
import kiui
# %cd ..
# Out:
# /content/Fourier123
# /content/Fourier123/nvdiffrast
# /content/Fourier123
# /content/Fourier123/kiuikit
# /content/Fourier123

# %%
# simple knn
# %cd simple-knn
# !python setup.py install > /dev/null 2>&1

# %cd build/lib.linux-x86_64-cpython-310

from simple_knn._C import distCUDA2

# %cd ../../..
# Out:
# /content/Fourier123/simple-knn
# /content/Fourier123/simple-knn/build/lib.linux-x86_64-cpython-310
# /content/Fourier123

# %%
# diff-gaussian-rasterization
# !git clone --recursive https://github.com/ashawkey/diff-gaussian-rasterization > /dev/null 2>&1
# %cd diff-gaussian-rasterization


# !CXXFLAGS="-D_GLIBCXX_USE_CXX11_ABI=1 -w" python setup.py build_ext --inplace > /dev/null 2>&1

from diff_gaussian_rasterization import (
    GaussianRasterizationSettings,
    GaussianRasterizer,
)

# %cd ..
# Out:
# /content/Fourier123/diff-gaussian-rasterization
# /content/Fourier123

# %% [markdown]
# Pretrained LGM

# %%
# !mkdir pretrained && cd pretrained
# %cd pretrained
# !wget -c https://huggingface.co/ashawkey/LGM/resolve/main/model_fp16_fixrot.safetensors > /dev/null
# %cd ..
# Out:
# /content/Fourier123/pretrained
# --2024-12-03 19:31:21--  https://huggingface.co/ashawkey/LGM/resolve/main/model_fp16_fixrot.safetensors
# Resolving huggingface.co (huggingface.co)... 13.35.210.77, 13.35.210.66, 13.35.210.114, ...
# Connecting to huggingface.co (huggingface.co)|13.35.210.77|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/81/5c/815ca7d304c775226c89dc3b5bdb666e68555d4bf881050ec3d3b414f2c9c57b/744d6324656342c64f871308e73db97f0eb51858d94329b30090e986a6d050ab?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model_fp16_fixrot.safetensors%3B+filename%3D%22model_fp16_fixrot.safetensors%22%3B&Expires=1733513482&Policy=&Signature=R1J%7EevIkeyDinR69ypoyXMx7jyMD0XG4zBNyYxiHIdDw2pb91bsR5bOcwY8dEkBkwzildsqRdUZeYPyYteXe5vXCVkgeE6v9MCmdSHz1YNEikKfWUPkxP45HFdLuOc6BH1Us2zALCoC7y5HW%7ESQUKaDgRPlT0P9AY%7EE33OX9NYU6aZs-7TEvsGBJrzs0QuVl-LUCScI1tNcqPDAHlBfFovJ%7Exj52Q8bWFAnY3UdB89Uu4xKIKvrC6BtZBw2v6%7EDH7zB39QU6JwIGdsi%7EqQWzbmY4GNW-NSK843DH6GzdOexKIzbLZ7uiVzuc1YTbqwlfZv0nMoiKly43bkTESF4Mbg__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2024-12-03 19:31:22--  https://cdn-lfs-us-1.hf.co/repos/81/5c/815ca7d304c775226c89dc3b5bdb666e68555d4bf881050ec3d3b414f2c9c57b/744d6324656342c64f871308e73db97f0eb51858d94329b30090e986a6d050ab?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model_fp16_fixrot.safetensors%3B+filename%3D%22model_fp16_fixrot.safetensors%22%3B&Expires=1733513482&Policy=&Signature=R1J%7EevIkeyDinR69ypoyXMx7jyMD0XG4zBNyYxiHIdDw2pb91bsR5bOcwY8dEkBkwzildsqRdUZeYPyYteXe5vXCVkgeE6v9MCmdSHz1YNEikKfWUPkxP45HFdLuOc6BH1Us2zALCoC7y5HW%7ESQUKaDgRPlT0P9AY%7EE33OX9NYU6aZs-7TEvsGBJrzs0QuVl-LUCScI1tNcqPDAHlBfFovJ%7Exj52Q8bWFAnY3UdB89Uu4xKIKvrC6BtZBw2v6%7EDH7zB39QU6JwIGdsi%7EqQWzbmY4GNW-NSK843DH6GzdOexKIzbLZ7uiVzuc1YTbqwlfZv0nMoiKly43bkTESF4Mbg__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 13.33.88.42, 13.33.88.63, 13.33.88.68, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|13.33.88.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 830126160 (792M) [binary/octet-stream]
# Saving to: ‘model_fp16_fixrot.safetensors’
#
# model_fp16_fixrot.s 100%[===================>] 791.67M  40.2MB/s    in 19s
#
# 2024-12-03 19:31:41 (40.9 MB/s) - ‘model_fp16_fixrot.safetensors’ saved [830126160/830126160]
#
# /content/Fourier123

# %% [markdown]
# Finetuning

# %%
from zero123 import Zero123Pipeline

class BrainScanToImagePipeline(Zero123Pipeline):
    def __init__(self, *args, encoder_weights, decoder_weights, **kwargs):
        super().__init__(*args, **kwargs)

        self.vae.decoder.load_state_dict(encoder_weights, strict=False)
        self.vae.encoder.load_state_dict(decoder_weights, strict=False)

    def _encode_brain_scan(self, brain_scan):
        # Normalize the input if needed
        brain_scan = (brain_scan - 0.5) * 2.0  # Scale to [-1, 1]

        # Use the decoder as the encoder
        latents = self.vae.decode(brain_scan).latent_dist.mode()  # Swapped role
        return latents

    def _decode_image(self, latents):
        # Use the encoder as the decoder
        images = self.vae.encode(latents).sample()  # Swapped role

        # Rescale the output to [0, 1]
        images = (images / 2 + 0.5).clamp(0, 1)
        return images

    @torch.no_grad()
    def __call__(self, brain_scan, **kwargs):
        # Encode brain scan into latents
        latents = self._encode_brain_scan(brain_scan)

        # Decode latents into an image
        image = self._decode_image(latents)

        return image

# %%
from safetensors.torch import load_file

state_dict = load_file('pretrained/model_fp16_fixrot.safetensors')

# Extract encoder weights
encoder_weights = {k: v for k, v in state_dict.items() if k.startswith('unet.down_blocks') or k.startswith('unet.conv_in')}

# Extract decoder weights
decoder_weights = {k: v for k, v in state_dict.items() if k.startswith('unet.up_blocks') or k.startswith('unet.conv_out')}

# Print the keys to verify
print("Encoder Weights:", encoder_weights.keys())
print("Decoder Weights:", decoder_weights.keys())
# Out:
# Encoder Weights: dict_keys(['unet.conv_in.bias', 'unet.conv_in.weight', 'unet.down_blocks.0.downsample.bias', 'unet.down_blocks.0.downsample.weight', 'unet.down_blocks.0.nets.0.conv1.bias', 'unet.down_blocks.0.nets.0.conv1.weight', 'unet.down_blocks.0.nets.0.conv2.bias', 'unet.down_blocks.0.nets.0.conv2.weight', 'unet.down_blocks.0.nets.0.norm1.bias', 'unet.down_blocks.0.nets.0.norm1.weight', 'unet.down_blocks.0.nets.0.norm2.bias', 'unet.down_blocks.0.nets.0.norm2.weight', 'unet.down_blocks.0.nets.1.conv1.bias', 'unet.down_blocks.0.nets.1.conv1.weight', 'unet.down_blocks.0.nets.1.conv2.bias', 'unet.down_blocks.0.nets.1.conv2.weight', 'unet.down_blocks.0.nets.1.norm1.bias', 'unet.down_blocks.0.nets.1.norm1.weight', 'unet.down_blocks.0.nets.1.norm2.bias', 'unet.down_blocks.0.nets.1.norm2.weight', 'unet.down_blocks.1.downsample.bias', 'unet.down_blocks.1.downsample.weight', 'unet.down_blocks.1.nets.0.conv1.bias', 'unet.down_blocks.1.nets.0.conv1.weight', 'unet.down_blocks.1.nets.0.conv2.bias', 'unet.down_blocks.1.nets.0.conv2.weight', 'unet.down_blocks.1.nets.0.norm1.bias', 'unet.down_blocks.1.nets.0.norm1.weight', 'unet.down_blocks.1.nets.0.norm2.bias', 'unet.down_blocks.1.nets.0.norm2.weight', 'unet.down_blocks.1.nets.0.shortcut.bias', 'unet.down_blocks.1.nets.0.shortcut.weight', 'unet.down_blocks.1.nets.1.conv1.bias', 'unet.down_blocks.1.nets.1.conv1.weight', 'unet.down_blocks.1.nets
# Decoder Weights: dict_keys(['unet.conv_out.bias', 'unet.conv_out.weight', 'unet.up_blocks.0.attns.0.attn.proj.bias', 'unet.up_blocks.0.attns.0.attn.proj.weight', 'unet.up_blocks.0.attns.0.attn.qkv.weight', 'unet.up_blocks.0.attns.0.norm.bias', 'unet.up_blocks.0.attns.0.norm.weight', 'unet.up_blocks.0.attns.1.attn.proj.bias', 'unet.up_blocks.0.attns.1.attn.proj.weight', 'unet.up_blocks.0.attns.1.attn.qkv.weight', 'unet.up_blocks.0.attns.1.norm.bias', 'unet.up_blocks.0.attns.1.norm.weight', 'unet.up_blocks.0.attns.2.attn.proj.bias', 'unet.up_blocks.0.attns.2.attn.proj.weight', 'unet.up_blocks.0.attns.2.attn.qkv.weight', 'unet.up_blocks.0.attns.2.norm.bias', 'unet.up_blocks.0.attns.2.norm.weight', 'unet.up_blocks.0.nets.0.conv1.bias', 'unet.up_blocks.0.nets.0.conv1.weight', 'unet.up_blocks.0.nets.0.conv2.bias', 'unet.up_blocks.0.nets.0.conv2.weight', 'unet.up_blocks.0.nets.0.norm1.bias', 'unet.up_blocks.0.nets.0.norm1.weight', 'unet.up_blocks.0.nets.0.norm2.bias', 'unet.up_blocks.0.nets.0.norm2.weight', 'unet.up_blocks.0.nets.0.shortcut.bias', 'unet.up_blocks.0.nets.0.shortcut.weight', 'unet.up_blocks.0.nets.1.conv1.bias', 'unet.up_blocks.0.nets.1.conv1.weight', 'unet.up_blocks.0.nets.1.conv2.bias', 'unet.up_blocks.0.nets.1.conv2.weight', 'unet.up_blocks.0.nets.1.norm1.bias', 'unet.up_blocks.0.nets.1.norm1.weight', 'unet.up_blocks.0.nets.1.norm2.bias', 'unet.up_blocks.0.nets.1.norm2.weight', 'unet.up_blocks.0.nets.1.shortcut.bias', 'unet.up_blocks.0.nets.1.shortcut.weight', 'unet.up_blocks.0.nets.2.conv1.bias', 'unet.up_blocks.0.nets.2.conv1.weight', 'unet.up_blocks.0.nets.2.conv2.bias', 'unet.up_blocks.0.nets.2.conv2.weight', 'unet.up_blocks.0.nets.2.norm1.bias', 'unet.up_blocks.0.nets.2.norm1.weight', 'unet.up_blocks.0.nets.2.norm2.bias', 'unet.up_blocks.0.nets.2.norm2.weight', 'unet.up_blocks.0.nets.2.shortcut.bias', 'unet.up_blocks.0.nets.2.shortcut.weight', 'unet.up_blocks.0.upsample.bias', 'unet.up_blocks.0.upsample.weight', 'unet.up_blocks.1.attns.0.attn.proj.bias', 'unet.up_blocks.1.attns.0.attn.proj.weight', 'unet.up_blocks.1.attns.0.attn.qkv.weight', 'unet.up_blocks.1.attns.0.norm.bias', 'unet.up_blocks.1.attns.0.norm.weight', 'unet.up_blocks.1.attns.1.attn.proj.bias', 'unet.up_blocks.1.attns.1.attn.proj.weight', 'unet.up_blocks.1.attns.1.attn.qkv.weight', 'unet.up_blocks.1.attns.1.norm.bias', 'unet.up_blocks.1.attns.1.norm.weight', 'unet.up_blocks.1.attns.2.attn.proj.bias', 'unet.up_blocks.1.attns.2.attn.proj.weight', 'unet.up_blocks.1.attns.2.attn.qkv.weight', 'unet.up_blocks.1.attns.2.norm.bias', 'unet.up_blocks.1.attns.2.norm.weight', 'unet.up_blocks.1.nets.0.conv1.bias', 'unet.up_blocks.1.nets.0.conv1.weight', 'unet.up_blocks.1.nets.0.conv2.bias', 'unet.up_blocks.1.nets.0.conv2.weight', 'unet.up_blocks.1.nets.0.norm1.bias', 'unet.up_blocks.1.nets.0.norm1.weight', 'unet.up_blocks.1.nets.0.norm2.bias', 'unet.up_blocks.1.nets.0.norm2.weight', 'unet.up_blocks.1.nets.0.shortcut.bias', 'unet.up_blocks.1.nets.0.shortcut.weight', 'unet.up_blocks.1.nets.1.conv1.bias', 'unet.up_blocks.1.nets.1.conv1.weight', 'unet.up_blocks.1.nets.1.conv2.bias', 'unet.up_blocks.1.nets.1.conv2.weight', 'unet.up_blocks.1.nets.1.norm1.bias', 'unet.up_blocks.1.nets.1.norm1.weight', 'unet.up_blocks.1.nets.1.norm2.bias', 'unet.up_blocks.1.nets.1.norm2.weight', 'unet.up_blocks.1.nets.1.shortcut.bias', 'unet.up_blocks.1.nets.1.shortcut.weight', 'unet.up_blocks.1.nets.2.conv1.bias', 'unet.up_blocks.1.nets.2.conv1.weight', 'unet.up_blocks.1.nets.2.conv2.bias', 'unet.up_blocks.1.nets.2.conv2.weight', 'unet.up_blocks.1.nets.2.norm1.bias', 'unet.up_blocks.1.nets.2.norm1.weight', 'unet.up_blocks.1.nets.2.norm2.bias', 'unet.up_blocks.1.nets.2.norm2.weight', 'unet.up_blocks.1.nets.2.shortcut.bias', 'unet.up_blocks.1.nets.2.shortcut.weight', 'unet.up_blocks.1.upsample.bias', 'unet.up_blocks.1.upsample.weight', 'unet.up_blocks.2.attns.0.attn.proj.bias', 'unet.up_blocks.2.attns.0.attn.proj.weight', 'unet.up_blocks.2.attns.0.attn.qkv.weight', 'unet.up_blocks.2. ...

# %%
print(state_dict.keys())
# Out:
# dict_keys(['conv.bias', 'conv.weight', 'unet.conv_in.bias', 'unet.conv_in.weight', 'unet.conv_out.bias', 'unet.conv_out.weight', 'unet.down_blocks.0.downsample.bias', 'unet.down_blocks.0.downsample.weight', 'unet.down_blocks.0.nets.0.conv1.bias', 'unet.down_blocks.0.nets.0.conv1.weight', 'unet.down_blocks.0.nets.0.conv2.bias', 'unet.down_blocks.0.nets.0.conv2.weight', 'unet.down_blocks.0.nets.0.norm1.bias', 'unet.down_blocks.0.nets.0.norm1.weight', 'unet.down_blocks.0.nets.0.norm2.bias', 'unet.down_blocks.0.nets.0.norm2.weight', 'unet.down_blocks.0.nets.1.conv1.bias', 'unet.down_blocks.0.nets.1.conv1.weight', 'unet.down_blocks.0.nets.1.conv2.bias', 'unet.down_blocks.0.nets.1.conv2.weight', 'unet.down_blocks.0.nets.1.norm1.bias', 'unet.down_blocks.0.nets.1.norm1.weight', 'unet.down_blocks.0.nets.1.norm2.bias', 'unet.down_blocks.0.nets.1.norm2.weight', 'unet.down_blocks.1.downsample
conv1.bias', 'unet.down_blocks.3.nets.1.conv1.weight', 'unet.down_blocks.3.nets.1.conv2.bias', 'unet.down_blocks.3.nets.1.conv2.weight', 'unet.down_blocks.3.nets.1.norm1.bias', 'unet.down_blocks.3.nets.1.norm1.weight', 'unet.down_blocks.3.nets.1.norm2.bias', 'unet.down_blocks.3.nets.1.norm2.weight', 'unet.down_blocks.4.attns.0.attn.proj.bias', 'unet.down_blocks.4.attns.0.attn.proj.weight', 'unet.down_blocks.4.attns.0.attn.qkv.weight', 'unet.down_blocks.4.attns.0.norm.bias', 'unet.down_blocks.4.attns.0.norm.weight', 'unet.down_ ...

# %%
from main import GUI

# %%
path = '/path/to/your/model_checkpoint.ply'

# !python main.py --config configs/image.yaml --load {path} --train

# %% [markdown]
# Inference and prediction

# %%
image = "Screenshot_rgba"
image_path = "data/"+image+".png"

# !python process.py data/Screenshot.png --size 512
img = Image.open(image_path).convert("RGB")
img.save(image_path, format='PNG')

# !python infer_lgm.py big --resume pretrained/model_fp16_fixrot.safetensors --workspace workspace --test_path {image_path} > /dev/null 2>&1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !chmod +r data/{image}.png

# %%
# !pwd
# Out:
# /content/Fourier123

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --config configs/image.yaml input={image_path} save_path=output_name load=workspace/{image}.ply
# Out:
# [INFO] load image from data/Screenshot_rgba.png...
# Number of points at loading :  43219
# [INFO] loading SD...
# 2024-10-28 00:53:19.724932: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-28 00:53:19.749797: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-28 00:53:19.757549: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-28 00:53:21.274683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# model_index.json: 100% 543/543 [00:00<00:00, 3.36MB/s]
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json: 100% 342/342 [00:00<00:00, 2.95MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:02,  5.16it/s]
# text_encoder/config.json: 100% 613/613 [00:00<00:00, 5.73MB/s]
#
# scheduler/scheduler_config.json: 100% 346/346 [00:00<00:00, 3.41MB/s]
#
# tokenizer/special_tokens_map.json: 100% 460/460 [00:00<00:00, 4.53MB/s]
#
# tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# tokenizer/tokenizer_config.json: 100% 807/807 [00:00<00:00, 6.73MB/s]
#
#
# tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# unet/config.json: 100% 911/911 [00:00<00:00, 6.61MB/s]
#
#
#
# vae/config.json: 100% 553/553 [00:00<00:00, 5.44MB/s]
#
#
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 3.65MB/s]
#
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.38MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.46G [00:00<?, ?B/s]
#
#
# model.safetensors:   0% 0.00/1.36G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:03, 103MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.46G [00:00<00:37, 92.8MB/s]
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:01, 161MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 31.5M/3.46G [00:00<00:22, 156MB/s]
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:01, 181MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 62.9M/3.46G [00:00<00:17, 193MB/s]
#
#
# model.safetensors:   1% 10.5M/1.36G [00:00<00:44, 30.1MB/s]
# diffusion_pytorch_model.safetensors:  22% 73.4M/335M [00:00<00:01, 153MB/s]
#
#
# model.safetensors:   2% 21.0M/1.36G [00:00<00:32, 41.7MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 83.9M/3.46G [00:00<00:24, 137MB/s]
#
#
# model.safetensors:   2% 31.5M/1.36G [00:00<00:24, 53.5MB/s]
# diffusion_pytorch_model.safetensors:  28% 94.4M/335M [00:00<00:02, 110MB/s]
#
#
# model.safetensors:   3% 41.9M/1.36G [00:00<00:20, 65.8MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 105M/3.46G [00:00<00:29, 112MB/s]
#
#
# model.safetensors:   4% 52.4M/1.36G [00:00<00:18, 72.0MB/s]
# diffusion_pytorch_model.safetensors:  34% 115M/335M [00:00<00:02, 105MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 126M/3.46G [00:01<00:32, 104MB/s]
#
#
# model.safetensors:   5% 73.4M/1.36G [00:01<00:15, 83.3MB/s]
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:01<00:01, 110MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 147M/3.46G [00:01<00:29, 114MB/s]
#
#
# model.safetensors:   6% 83.9M/1.36G [00:01<00:15, 81.1MB/s]
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:01<00:01, 106MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 168M/3.46G [00:01<00:28, 115MB/s]
#
#
# model.safetensors:   8% 105M/1.36G [00:01<00:13, 96.3MB/s]
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:01<00:01, 119MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 189M/3.46G [00:01<00:28, 114MB/s]
#
#
# model.safetensors:   9% 126M/1.36G [00:01<00:12, 96.7MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 210M/3.46G [00:01<00:26, 122MB/s]
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:01<00:01, 106MB/s]
#
#
# model.safetensors:  10% 136M/1.36G [00:01<00:12, 96.6MB/s]
#
#
# model.safetensors:  11% 147M/1.36G [00:01<00:13, 93.3MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 231M/3.46G [00:01<00:27, 116MB/s]
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:01<00:01, 103MB/s]
#
#
# model.safetensors:  12% 157M/1.36G [00:02<00:14, 83.3MB/s]
#
#
# model.safetensors:  12% 168M/1.36G [00:02<00:13, 86.6MB/s]
# diffusion_pytorch_model.safetensors:  72% 241M/335M [00:02<00:01, 90.1MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 252M/3.46G [00:02<00:35, 90.6MB/s]
#
#
# model.safetensors:  13% 178M/1.36G [00:02<00:15, 74.0MB/s]
# diffusion_pytorch_model.safetensors:  75% 252M/335M [00:02<00:01, 79.1MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 262M/3.46G [00:02<00:41, 78.0MB/s]
#
#
# model.safetensors:  14% 189M/1.36G [00:02<00:17, 65.3MB/s]
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:02<00:01, 68.8MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 273M/3.46G [00:02<00:45, 69.6MB/s]
# diffusion_pytorch_model.safetensors:  81% 273M/335M [00:02<00:00, 63.3MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 283M/3.46G [00:02<00:49, 63.8MB/s]
#
#
# model.safetensors:  15% 199M/1.36G [00:02<00:25, 44.9MB/s]
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:03<00:00, 58.9MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 294M/3.46G [00:03<00:54, 58.1MB/s]
#
#
# model.safetensors:  16% 220M/1.36G [00:03<00:19, 59.2MB/s]
# diffusion_pytorch_model.safetensors:  88% 294M/335M [00:03<00:00, 62.5MB/s]
#
#
# model.safetensors:  17% 231M/1.36G [00:03<00:17, 64.6MB/s]
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:03<00:00, 69.6MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 315M/3.46G [00:03<00:46, 68.0MB/s]
#
#
# model.safetensors:  18% 252M/1.36G [00:03<00:14, 78.1MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 325M/3.46G [00:03<00:43, 71.6MB/s]
# diffusion_pytorch_model.safetensors:  97% 325M/335M [00:03<00:00, 85.7MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:03<00:00, 91.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 346M/3.46G [00:03<00:36, 84.7MB/s]
#
#
# model.safetensors:  21% 283M/1.36G [00:03<00:10, 99.4MB/s]
#
# diffusion_pytorch_model.safetensors:  11% 377M/3.46G [00:03<00:27, 111MB/s]
#
#
# model.safetensors:  23% 315M/1.36G [00:03<00:09, 113MB/s]
#
# diffusion_pytorch_model.safetensors:  12% 398M/3.46G [00:04<00:31, 98.5MB/s]
#
#
# model.safetensors:  25% 336M/1.36G [00:04<00:09, 106MB/s]
#
# diffusion_pytorch_model.safetensors:  12% 419M/3.46G [00:04<00:29, 102MB/s]
#
#
# model.safetensors:  26% 357M/1.36G [00:04<00:09, 105MB/s]
#
# diffusion_pytorch_model.safetensors:  13% 440M/3.46G [00:04<00:35, 84.0MB/s]
#
#
# model.safetensors:  28% 377M/1.36G [00:07<00:51, 19.3MB/s]
#
# diffusion_pytorch_model.safetensors:  13% 451M/3.46G [00:07<02:56, 17.0MB/s]
#
#
# model.safetensors:  29% 398M/1.36G [00:07<00:36, 26.5MB/s]
#
# diffusion_pytorch_model.safetensors:  14% 482M/3.46G [00:07<01:44, 28.5MB/s]
#
# diffusion_pytorch_model.safetensors:  15% 503M/3.46G [00:07<01:18, 37.8MB/s]
#
#
# model.safetensors:  31% 419M/1.36G [00:07<00:27, 33.7MB/s]
#
# diffusion_pytorch_model.safetensors:  15% 524M/3.46G [00:07<01:01, 48.1MB/s]
#
#
# model.safetensors:  32% 440M/1.36G [00:08<00:21, 42.1MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 545M/3.46G [00:08<00:50, 57.4MB/s]
#
#
# model.safetensors:  34% 461M/1.36G [00:08<00:17, 52.9MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 566M/3.46G [00:08<00:42, 67.7MB/s]
#
#
# model.safetensors:  35% 482M/1.36G [00:08<00:13, 65.6MB/s]
#
# diffusion_pytorch_model.safetensors:  17% 587M/3.46G [00:08<00:34, 83.5MB/s]
#
#
# model.safetensors:  37% 503M/1.36G [00:08<00:12, 67.8MB/s]
#
# diffusion_pytorch_model.safetensors:  18% 608M/3.46G [00:08<00:37, 76.1MB/s]
#
#
# model.safetensors:  39% 524M/1.36G [00:08<00:11, 76.1MB/s]
#
# diffusion_pytorch_model.safetensors:  18% 629M/3.46G [00:08<00:33, 84.8MB/s]
#
#
# model.safetensors:  40% 545M/1.36G [00:09<00:09, 84.3MB/s]
#
# diffusion_pytorch_model.safetensors:  19% 650M/3.46G [00:09<00:31, 90.5MB/s]
#
#
# model.safetensors:  42% 566M/1.36G [00:09<00:11, 71.1MB/s]
#
# diffusion_pytorch_model.safetensors:  19% 671M/3.46G [00:12<02:42, 17.2MB/s]
#
#
# model.safetensors:  42% 577M/1.36G [00:13<01:04, 12.1MB/s]
#
# diffusion_pytorch_model.safetensors:  20% 682M/3.46G [00:13<03:01, 15.3MB/s]
#
#
# model.safetensors:  45% 608M/1.36G [00:13<00:36, 20.4MB/s]
#
# diffusion_pytorch_model.safetensors:  20% 703M/3.46G [00:13<02:05, 22.0MB/s]
#
#
# model.safetensors:  46% 629M/1.36G [00:13<00:26, 27.5MB/s]
#
# diffusion_pytorch_model.safetensors:  21% 724M/3.46G [00:14<01:32, 29.7MB/s]
#
# diffusion_pytorch_model.safetensors:  21% 734M/3.46G [00:14<01:19, 34.2MB/s]
#
#
# model.safetensors:  48% 650M/1.36G [00:14<00:20, 35.0MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 755M/3.46G [00:14<00:59, 45.6MB/s]
#
#
# model.safetensors:  49% 671M/1.36G [00:14<00:15, 43.7MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 776M/3.46G [00:14<00:44, 60.4MB/s]
#
#
# model.safetensors:  51% 692M/1.36G [00:14<00:11, 55.9MB/s]
#
# diffusion_pytorch_model.safetensors:  23% 797M/3.46G [00:14<00:35, 75.1MB/s]
#
#
# model.safetensors:  52% 713M/1.36G [00:14<00:09, 68.4MB/s]
#
# diffusion_pytorch_model.safetensors:  24% 818M/3.46G [00:14<00:30, 86.8MB/s]
#
#
# model.safetensors:  54% 734M/1.36G [00:14<00:07, 82.4MB/s]
#
# diffusion_pytorch_model.safetensors:  24% 839M/3.46G [00:14<00:26, 97.4MB/s]
#
#
# model.safetensors:  55% 755M/1.36G [00:14<00:07, 83.7MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 860M/3.46G [00:15<00:24, 106MB/s]
#
#
# model.safetensors:  57% 776M/1.36G [00:15<00:05, 97.8MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 881M/3.46G [00:15<00:21, 121MB/s]
#
#
# model.safetensors:  59% 797M/1.36G [00:15<00:05, 101MB/s]
#
# diffusion_pytorch_model.safetensors:  26% 902M/3.46G [00:15<00:21, 121MB/s]
#
#
# model.safetensors:  60% 818M/1.36G [00:15<00:04, 114MB/s]
#
# diffusion_pytorch_model.safetensors:  27% 923M/3.46G [00:15<00:20, 126MB/s]
#
#
# model.safetensors:  62% 839M/1.36G [00:15<00:04, 125MB/s]
#
# diffusion_pytorch_model.safetensors:  27% 944M/3.46G [00:15<00:17, 142MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 965M/3.46G [00:15<00:17, 141MB/s]
#
#
# model.safetensors:  63% 860M/1.36G [00:15<00:04, 110MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 986M/3.46G [00:15<00:18, 131MB/s]
#
#
# model.safetensors:  65% 881M/1.36G [00:16<00:04, 103MB/s]
#
# diffusion_pytorch_model.safetensors:  29% 1.01G/3.46G [00:16<00:20, 118MB/s]
#
#
# model.safetensors:  66% 902M/1.36G [00:16<00:03, 119MB/s]
#
# diffusion_pytorch_model.safetensors:  30% 1.03G/3.46G [00:16<00:21, 112MB/s]
#
#
# model.safetensors:  68% 923M/1.36G [00:16<00:04, 108MB/s]
#
# diffusion_pytorch_model.safetensors:  30% 1.05G/3.46G [00:16<00:20, 121MB/s]
#
#
# model.safetensors:  69% 944M/1.36G [00:16<00:03, 120MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 1.07G/3.46G [00:16<00:18, 130MB/s]
#
#
# model.safetensors:  72% 975M/1.36G [00:16<00:02, 137MB/s]
#
#
# model.safetensors:  73% 996M/1.36G [00:16<00:02, 123MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 1.09G/3.46G [00:16<00:24, 95.7MB/s]
#
#
# model.safetensors:  75% 1.03G/1.36G [00:17<00:02, 149MB/s]
#
#
# model.safetensors:  77% 1.05G/1.36G [00:17<00:02, 151MB/s]
#
# diffusion_pytorch_model.safetensors:  32% 1.11G/3.46G [00:17<00:26, 90.2MB/s]
#
#
# model.safetensors:  79% 1.07G/1.36G [00:17<00:01, 162MB/s]
#
# diffusion_pytorch_model.safetensors:  33% 1.13G/3.46G [00:17<00:23, 99.0MB/s]
#
#
# model.safetensors:  80% 1.09G/1.36G [00:17<00:01, 156MB/s]
#
#
# model.safetensors:  82% 1.11G/1.36G [00:17<00:01, 151MB/s]
#
#
# model.safetensors:  83% 1.13G/1.36G [00:17<00:01, 158MB/s]
#
# diffusion_pytorch_model.safetensors:  33% 1.15G/3.46G [00:17<00:30, 76.3MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 1.16G/3.46G [00:17<00:28, 79.6MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 1.18G/3.46G [00:18<00:23, 96.9MB/s]
#
#
# model.safetensors:  85% 1.15G/1.36G [00:18<00:01, 105MB/s]
#
# diffusion_pytorch_model.safetensors:  35% 1.21G/3.46G [00:18<00:19, 115MB/s]
#
#
# model.safetensors:  86% 1.17G/1.36G [00:18<00:01, 117MB/s]
#
# diffusion_pytorch_model.safetensors:  35% 1.23G/3.46G [00:18<00:17, 129MB/s]
#
#
# model.safetensors:  88% 1.20G/1.36G [00:18<00:01, 134MB/s]
#
# diffusion_pytorch_model.safetensors:  36% 1.25G/3.46G [00:18<00:15, 142MB/s]
#
#
# model.safetensors:  90% 1.23G/1.36G [00:18<00:00, 157MB/s]
#
# diffusion_pytorch_model.safetensors:  37% 1.27G/3.46G [00:18<00:16, 133MB/s]
#
#
# model.safetensors:  92% 1.25G/1.36G [00:18<00:00, 142MB/s]
#
# diffusion_pytorch_model.safetensors:  37% 1.29G/3.46G [00:21<01:57, 18.6MB/s]
#
#
# model.safetensors:  93% 1.27G/1.36G [00:21<00:04, 20.4MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 1.31G/3.46G [00:22<01:24, 25.5MB/s]
#
#
# model.safetensors:  95% 1.29G/1.36G [00:22<00:02, 27.2MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 1.33G/3.46G [00:22<01:02, 34.4MB/s]
#
#
# model.safetensors:  96% 1.31G/1.36G [00:22<00:01, 35.7MB/s]
#
# diffusion_pytorch_model.safetensors:  39% 1.35G/3.46G [00:22<00:48, 43.3MB/s]
#
#
# model.safetensors:  98% 1.33G/1.36G [00:22<00:00, 43.8MB/s]
#
# diffusion_pytorch_model.safetensors:  40% 1.37G/3.46G [00:22<00:39, 52.9MB/s]
#
#
# model.safetensors:  99% 1.35G/1.36G [00:22<00:00, 54.0MB/s]
#
# model.safetensors: 100% 1.36G/1.36G [00:27<00:00, 48.7MB/s]
# Fetching 13 files:  38% 5/13 [00:28<00:48,  6.04s/it]
#
# diffusion_pytorch_model.safetensors:  41% 1.41G/3.46G [00:28<02:54, 11.8MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 1.43G/3.46G [00:28<02:00, 17.0MB/s]
#
# diffusion_pytorch_model.safetensors:  42% 1.45G/3.46G [00:28<01:24, 23.9MB/s]
#
# diffusion_pytorch_model.safetensors:  43% 1.48G/3.46G [00:28<00:52, 37.6MB/s]
#
# diffusion_pytorch_model.safetensors:  43% 1.50G/3.46G [00:28<00:41, 47.4MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 1.52G/3
B/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.09G/3.46G [00:43<00:04, 91.2MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.11G/3.46G [00:43<00:03, 105MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.14G/3.46G [00:43<00:02, 110MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.16G/3.46G [00:43<00:02, 127MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.18G/3.46G [00:43<00:02, 132MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.20G/3.46G [00:43<00:01, 143MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.22G/3.46G [00:43<00:01, 155MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.24G/3.46G [00:43<00:01, 160MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.26G/3.46G [00:44<00:01, 157MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.29G/3.46G [00:44<00:00, 173MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.31G/3.46G [00:44<00:00, 179MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.33G/3.46G [00:44<00:00, 173MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.36G/3.46G [00:44<00:00, 179MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.39G/3.46G [00:44<00:00, 187MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.41G/3.46G [00:44<00:00, 168MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.43G/3.46G [00:48<00:01, 19.0MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.46G/3.46G [00:48<00:00, 71.1MB/s]
# Fetching 13 files: 100% 13/13 [00:49<00:00,  3.78s/it]
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loading pipeline components...: 100% 6/6 [00:25<00:00,  4.27s/it]
# [INFO] loaded SD!
# [INFO] loading zero123...
# model_index.json: 100% 562/562 [00:00<00:00, 4.05MB/s]
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# clip_camera_projection/config.json: 100% 132/132 [00:00<00:00, 1.21MB/s]
# Fetching 12 files:   8% 1/12 [00:00<00:01,  5.81it/s]
# (…)ature_extractor/preprocessor_config.json: 100% 546/546 [00:00<00:00, 5.03MB/s]
#
# clip_camera_projection/zero123.py: 100% 30.6k/30.6k [00:00<00:00, 66.0MB/s]
#
# unet/config.json: 100% 1.78k/1.78k [00:00<00:00, 16.1MB/s]
#
# image_encoder/config.json: 100% 585/585 [00:00<00:00, 5.77MB/s]
#
# scheduler/scheduler_config.json: 100% 502/502 [00:00<00:00, 4.03MB/s]
#
# model.safetensors:   0% 0.00/608M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors: 100% 1.19M/1.19M [00:00<00:00, 23.6MB/s]
# Fetching 12 files:  17% 2/12 [00:00<00:01,  5.64it/s]
#
# vae/config.json: 100% 601/601 [00:00<00:00, 4.45MB/s]
#
# model.safetensors:   2% 10.5M/608M [00:00<00:16, 36.1MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/1.72G [00:00<?, ?B/s]
# model.safetensors:   3% 21.0M/608M [00:00<00:14, 39.2MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 10.5M/167M [00:00<00:04, 39.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 10.5M/1.72G [00:00<00:51, 33.0MB/s]
# model.safetensors:   5% 31.5M/608M [00:00<00:13, 41.5MB/s]
#
# diffusion_pytorch_model.safetensors:  13% 21.0M/167M [00:00<00:03, 39.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 21.0M/1.72G [00:00<00:45, 37.6MB/s]
# model.safetensors:   7% 41.9M/608M [00:01<00:13, 41.8MB/s]
#
# diffusion_pytorch_model.safetensors:  19% 31.5M/167M [00:00<00:03, 41.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 31.5M/1.72G [00:00<00:42, 39.5MB/s]
# model.safetensors:   9% 52.4M/608M [00:01<00:13, 41.9MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 41.9M/167M [00:01<00:03, 41.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 41.9M/1.72G [00:01<00:41, 40.3MB/s]
# model.safetensors:  10% 62.9M/608M [00:01<00:12, 41.9MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 52.4M/167M [00:01<00:02, 41.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 52.4M/1.72G [00:01<00:44, 37.4MB/s]
# model.safetensors:  12% 73.4M/608M [00:01<00:12, 42.0MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 62.9M/167M [00:01<00:02, 41.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 62.9M/1.72G [00:01<00:42, 38.8MB/s]
# model.safetensors:  14% 83.9M/608M [00:02<00:12, 42.1MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 73.4M/167M [00:01<00:02, 41.2MB/s]
# model.safetensors:  16% 94.4M/608M [00:02<00:12, 42.1MB/s]
#
# diffusion_pytorch_model.safetensors:  50% 83.9M/167M [00:02<00:02, 41.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 73.4M/1.72G [00:02<00:49, 33.3MB/s]
# model.safetensors:  17% 105M/608M [00:02<00:11, 42.3MB/s]
#
# diffusion_pytorch_model.safetensors:  56% 94.4M/167M [00:02<00:01, 41.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 83.9M/1.72G [00:02<00:45, 36.1MB/s]
# model.safetensors:  19% 115M/608M [00:02<00:11, 42.1MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 105M/167M [00:02<00:01, 42.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 94.4M/1.72G [00:02<00:42, 37.9MB/s]
# model.safetensors:  21% 126M/608M [00:03<00:11, 42.0MB/s]
#
# diffusion_pytorch_model.safetensors:  69% 115M/167M [00:02<00:01, 41.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 105M/1.72G [00:02<00:41, 38.7MB/s]
# model.safetensors:  22% 136M/608M [00:03<00:11, 42.3MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 126M/167M [00:05<00:03, 11.8MB/s]
# model.safetensors:  24% 147M/608M [00:05<00:36, 12.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 115M/1.72G [00:05<02:19, 11.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 126M/1.72G [00:05<01:42, 15.5MB/s]
# model.safetensors:  28% 168M/608M [00:05<00:21, 20.4MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 147M/167M [00:05<00:01, 19.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   8% 136M/1.72G [00:05<01:23, 19.1MB/s]
# model.safetensors:  29% 178M/608M [00:05<00:18, 23.4MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 157M/167M [00:05<00:00, 22.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 147M/1.72G [00:05<01:08, 22.9MB/s]
# model.safetensors:  31% 189M/608M [00:06<00:15, 26.4MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 167M/167M [00:05<00:00, 28.1MB/s]
#
#
#
# diffusion_pytorch_model.safetensors:   9% 157M/1.72G [00:06<00:59, 26.4MB/s]
# model.safetensors:  33% 199M/608M [00:06<00:13, 29.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 168M/1.72G [00:06<00:52, 29.7MB/s]
# model.safetensors:  34% 210M/608M [00:06<00:12, 32.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 178M/1.72G [00:06<00:47, 32.7MB/s]
# model.safetensors:  36% 220M/608M [00:06<00:11, 34.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  11% 189M/1.72G [00:06<00:43, 35.0MB/s]
# model.safetensors:  38% 231M/608M [00:07<00:10, 36.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 199M/1.72G [00:07<00:41, 36.7MB/s]
# model.safetensors:  40% 241M/608M [00:07<00:09, 38.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 210M/1.72G [00:07<00:39, 38.0MB/s]
# model.safetensors:  41% 252M/608M [00:07<00:09, 39.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 220M/1.72G [00:07<00:38, 39.1MB/s]
# model.safetensors:  43% 262M/608M [00:07<00:08, 39.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 231M/1.72G [00:07<00:37, 40.1MB/s]
# model.safetensors:  45% 273M/608M [00:08<00:08, 40.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  14% 241M/1.72G [00:08<01:14, 20.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 252M/1.72G [00:09<00:57, 25.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 262M/1.72G [00:09<00:47, 30.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 273M/1.72G [00:09<00:43, 33.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 283M/1.72G [00:09<00:40, 35.8MB/s]
# model.safetensors:  47% 283M/608M [00:10<00:24, 13.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  17% 294M/1.72G [00:10<00:37, 37.6MB/s]
# model.safetensors:  48% 294M/608M [00:10<00:17, 17.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 304M/1.72G [00:10<00:36, 39.0MB/s]
# model.safetensors:  50% 304M/608M [00:10<00:13, 22.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 315M/1.72G [00:10<00:35, 39.9MB/s]
# model.safetensors:  52% 315M/608M [00:10<00:11, 25.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  19% 325M/1.72G [00:10<00:34, 40.7MB/s]
# model.safetensors:  53% 325M/608M [00:11<00:09, 28.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  20% 336M/1.72G [00:10<00:33, 40.9MB/s]
# model.safetensors:  55% 336M/608M [00:11<00:08, 30.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  20% 346M/1.72G [00:11<00:33, 41.1MB/s]
# model.safetensors:  57% 346M/608M [00:11<00:07, 33.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 357M/1.72G [00:11<00:32, 41.4MB/s]
# model.safetensors:  59% 357M/608M [00:11<00:07, 35.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 367M/1.72G [00:11<00:32, 41.5MB/s]
# model.safetensors:  60% 367M/608M [00:12<00:06, 36.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 377M/1.72G [00:12<00:32, 41.3MB/s]
# model.safetensors:  62% 377M/608M [00:12<00:06, 36.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 388M/1.72G [00:12<00:32, 41.3MB/s]
# model.safetensors:  64% 388M/608M [00:12<00:05, 38.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 398M/1.72G [00:12<00:31, 41.3MB/s]
# model.safetensors:  66% 398M/608M [00:12<00:05, 37.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 409M/1.72G [00:12<00:31, 41.8MB/s]
# model.safetensors:  67% 409M/608M [00:13<00:05, 38.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 419M/1.72G [00:13<00:31, 41.2MB/s]
# model.safetensors:  69% 419M/608M [00:13<00:05, 36.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  25% 430M/1.72G [00:13<00:31, 41.5MB/s]
# model.safetensors:  71% 430M/608M [00:13<00:04, 37.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  26% 440M/1.72G [00:13<00:30, 41.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  26% 451M/1.72G [00:13<00:31, 40.1MB/s]
# model.safetensors:  72% 440M/608M [00:14<00:04, 36.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 461M/1.72G [00:14<00:30, 40.7MB/s]
# model.safetensors:  74% 451M/608M [00:14<00:04, 37.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 472M/1.72G [00:14<00:30, 41.3MB/s]
# model.safetensors:  76% 461M/608M [00:14<00:03, 39.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  28% 482M/1.72G [00:14<00:29, 41.7MB/s]
# model.safetensors:  78% 472M/608M [00:14<00:03, 40.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 493M/1.72G [00:14<00:29, 41.4MB/s]
# model.safetensors:  79% 482M/608M [00:15<00:03, 40.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 503M/1.72G [00:15<00:29, 41.7MB/s]
# model.safetensors:  81% 493M/608M [00:15<00:02, 40.7MB/s]
# model.safetensors:  83% 503M/608M [00:15<00:02, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 514M/1.72G [00:15<00:28, 41.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 524M/1.72G [00:15<00:28, 42.3MB/s]
# model.safetensors:  85% 514M/608M [00:15<00:02, 42.0MB/s]
# model.safetensors:  86% 524M/608M [00:16<00:01, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  31% 535M/1.72G [00:15<00:31, 38.0MB/s]
# model.safetensors:  88% 535M/608M [00:16<00:01, 42.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 545M/1.72G [00:16<00:26, 43.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 556M/1.72G [00:16<00:26, 43.6MB/s]
# model.safetensors:  90% 545M/608M [00:16<00:01, 42.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  33% 566M/1.72G [00:16<00:26, 43.1MB/s]
# model.safetensors:  91% 556M/608M [00:16<00:01, 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 577M/1.72G [00:16<00:26, 42.8MB/s]
# model.safetensors:  93% 566M/608M [00:17<00:00, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 587M/1.72G [00:17<00:26, 42.7MB/s]
# model.safetensors:  95% 577M/608M [00:17<00:00, 41.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 598M/1.72G [00:17<00:26, 42.3MB/s]
# model.safetensors:  97% 587M/608M [00:17<00:00, 41.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 608M/1.72G [00:17<00:26, 41.9MB/s]
# model.safetensors:  98% 598M/608M [00:17<00:00, 41.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36%
 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  80% 1.37G/1.72G [00:39<00:08, 42.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 1.38G/1.72G [00:40<00:07, 42.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 1.39G/1.72G [00:40<00:07, 42.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  82% 1.41G/1.72G [00:40<00:07, 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  82% 1.42G/1.72G [00:40<00:07, 42.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  83% 1.43G/1.72G [00:41<00:06, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  84% 1.44G/1.72G [00:41<00:06, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  84% 1.45G/1.72G [00:41<00:06, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  85% 1.46G/1.72G [00:41<00:06, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  85% 1.47G/1.72G [00:42<00:05, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  86% 1.48G/1.72G [00:42<00:05, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  87% 1.49G/1.72G [00:42<00:05, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  87% 1.50G/1.72G [00:42<00:05, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  88% 1.51G/1.72G [00:43<00:04, 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  88% 1.52G/1.72G [00:43<00:04, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  89% 1.53G/1.72G [00:43<00:04, 42.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  90% 1.54G/1.72G [00:43<00:04, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  90% 1.55G/1.72G [00:44<00:03, 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 1.56G/1.72G [00:44<00:03, 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 1.57G/1.72G [00:44<00:04, 36.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  92% 1.58G/1.72G [00:44<00:03, 44.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  93% 1.59G/1.72G [00:45<00:02, 43.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  93% 1.60G/1.72G [00:45<00:02, 43.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  94% 1.61G/1.72G [00:45<00:02, 43.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  95% 1.63G/1.72G [00:45<00:02, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  95% 1.64G/1.72G [00:46<00:01, 42.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  96% 1.65G/1.72G [00:46<00:01, 42.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  96% 1.66G/1.72G [00:46<00:01, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  97% 1.67G/1.72G [00:46<00:01, 42.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  98% 1.68G/1.72G [00:47<00:00, 41.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  98% 1.69G/1.72G [00:47<00:00, 42.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:  99% 1.70G/1.72G [00:47<00:00, 42.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  99% 1.71G/1.72G [00:47<00:00, 42.3MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 1.72G/1.72G [00:48<00:00, 35.7MB/s]
# Fetching 12 files: 100% 12/12 [00:48<00:00,  4.06s/it]
# Keyword arguments {'trust_remote_code': True} are not expected by Zero123Pipeline and will be ignored.
# Loading pipeline components...: 100% 6/6 [00:01<00:00,  3.71it/s]
# [INFO] loaded zero123!
# enable_sd:  True
# enable_zero123:  True
# _________________________________________________________
#   0% 0/400 [00:00<?, ?it/s]/content/Fourier123/FSDLoss.py:46: UserWarning: ComplexHalf support is experimental and many operators don't support it yet. (Triggered internally at ../aten/src/ATen/EmptyTensor.cpp:31.)
#   pred_freq = torch.fft.fft2(pred, norm='ortho')
#  10% 39/400 [00:24<03:22,  1.79it/s]Train Step: 40, loss_zero123: 41.43657302856445, loss_fsd: 23.882627487182617
#  20% 79/400 [00:46<02:58,  1.80it/s]Train Step: 80, loss_zero123: 167.48681640625, loss_fsd: 27.373228073120117
#  30% 119/400 [01:08<02:33,  1.83it/s]Train Step: 120, loss_zero123: 170.96844482421875, loss_fsd: 34.62257385253906
#  40% 159/400 [01:30<02:14,  1.79it/s]Train Step: 160, loss_zero123: 340.47601318359375, loss_fsd: 27.663631439208984
#  50% 199/400 [01:52<01:49,  1.83it/s]Train Step: 200, loss_zero123: 345.712646484375, loss_fsd: 27.350597381591797
#  60% 239/400 [02:14<01:28,  1.81it/s]Train Step: 240, loss_zero123: 238.8455352783203, loss_fsd: 46.009361267089844
#  70% 279/400 [02:37<01:08,  1.78it/s]Train Step: 280, loss_zero123: 382.52996826171875, loss_fsd: 43.409427642822266
#  80% 319/400 [02:59<00:44,  1.82it/s]Train Step: 320, loss_zero123: 81.00840759277344, loss_fsd: 55.93276596069336
#  90% 359/400 [03:21<00:22,  1.80it/s]Train Step: 360, loss_zero123: 13.700760841369629, loss_fsd: 14.741288185119629
# 100% 399/400 [03:43<00:00,  1.83it/s]Train Step: 400, loss_zero123: 0.2784418761730194, loss_fsd: 0.6077733039855957
# 100% 400/400 [03:44<00:00,  1.78it/s]
# [INFO] save model to logs/output_name_model.ply.

# %%
### 3D Gaussian visualization
# !CUDA_VISIBLE_DEVICES=0 python see.py --config configs/image.yaml workspace=workspace load=logs/output_name_model.ply
# Out:
# Number of points at loading :  40168

# %%
### Extract glb mesh from ply
# !python convert.py big --test_path workspace/{image}.ply
# Out:
# (  ●   ) GridEncoder: Setting up CUDA (This may take a few minutes the first time)
# Number of points at loading :  43219
# [INFO] fitting nerf...
# ( ●    ) NerfAcc: Setting up CUDA (This may take a few minutes the first time)
# MSE = 0.000844: 100% 512/512 [06:05<00:00,  1.40it/s]
# [INFO] finished fitting nerf!
# [INFO] marching cubes thresh: 10 (0.13568754494190216 ~ 364.51171875)
# [INFO] mesh cleaning: (70102, 3) --> (39408, 3), (140024, 3) --> (78637, 3)
# [INFO] mesh decimation: (39408, 3) --> (25066, 3), (78637, 3) --> (50000, 3)
# [INFO] fitting mesh...
# MSE = 0.003743:  25% 511/2048 [00:08<00:24, 62.06it/s][INFO] mesh cleaning: (25066, 3) --> (31070, 3), (50000, 3) --> (62003, 3)
# [INFO] mesh decimation: (31070, 3) --> (25050, 3), (62003, 3) --> (50000, 3)
# MSE = 0.003560:  50% 1018/2048 [00:20<00:16, 61.11it/s][INFO] mesh cleaning: (25050, 3) --> (29304, 3), (50000, 3) --> (58501, 3)
# [INFO] mesh decimation: (29304, 3) --> (25039, 3), (58501, 3) --> (50000, 3)
# MSE = 0.001328:  75% 1535/2048 [00:32<00:08, 60.97it/s][INFO] mesh cleaning: (25039, 3) --> (28704, 3), (50000, 3) --> (57319, 3)
# [INFO] mesh decimation: (28704, 3) --> (25036, 3), (57319, 3) --> (49999, 3)
# MSE = 0.001225: 100% 2048/2048 [00:43<00:00, 46.94it/s]
# [INFO] mesh cleaning: (25036, 3) --> (25035, 3), (49999, 3) --> (49999, 3)
# [INFO] finished fitting mesh!
# [INFO] uv unwrapping...
# [INFO] querying texture...
# [INFO] fitting mesh texture...
# MSE = 0.002175: 100% 512/512 [00:03<00:00, 154.22it/s]
# [INFO] finished fitting mesh texture!

# %%
# !ls -lh workspace/
# !ls -lh logs/
# !ls -lh output/
# Out:
# total 4.5M
# -rw-r--r-- 1 root root 1.5M Oct 26 23:25 cifar10_image_0.gif
# -rw-r--r-- 1 root root 1.5M Oct 27 00:50 cifar10_image_0.glb
# -rw-r--r-- 1 root root 142K Oct 26 23:25 cifar10_image_0.mp4
# -rw-r--r-- 1 root root 1.4M Oct 26 23:25 cifar10_image_0.ply
# -rw-r--r-- 1 root root  68K Oct 27 00:47 output.mp4
# total 596K
# -rw-r--r-- 1 root root 596K Oct 27 00:46 output_name_model.ply
# ls: cannot access 'output/': No such file or directory
